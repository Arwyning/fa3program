# %% [markdown]
# <a href="https://colab.research.google.com/github/Arwyning/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#faprog1(student information display)
student_name = input("What is your name? ")
student_age = input("how old are you? ")
student_course = input("what course are you taking? ")

print("Name: ",student_name)
print("age: ",student_age)
print("course: ",student_course)

# %%
#faprog2(pass or fail checker)
student_score = int(input("enter your score: "))
if student_score > 75:
    print("Passed")
else:
    print("Failed")

# %%
#faprog3(grading system)
student_name = input("enter your name: ")
student_score = int(input("enter your score: "))

if student_score >90:
      print("A")
else:
    if student_score >80:
        print("B")
    else:
        if student_score >70:
            print("C")
        else:
            print("F")
